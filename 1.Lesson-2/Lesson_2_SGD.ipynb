# %%
# %matplotlib inline
from fastai.basics import *

# %% [markdown]
# # Linear Regression problem
# The goal of linear regression is to fit a line to a set of points.

# %%
n=100

# %%
x = torch.ones(n,2) 
x[:,0].uniform_(-1.,1)
x[:5]
# Out:
# tensor([[-0.3887,  1.0000],
#         [-0.0993,  1.0000],
#         [ 0.5695,  1.0000],
#         [ 0.1953,  1.0000],
#         [ 0.1093,  1.0000]])

# %%
a = tensor(3.,2); a
# Out:
# tensor([3., 2.])

# %%
y = x@a + torch.rand(n)

# %%
plt.scatter(x[:,0], y);

# %% [markdown]
# You want to find parameters (weights) a such that you minimize the error between the points and the line x@a. Note that here a is unknown. For a regression problem the most common error function or loss function is the mean squared error.

# %%
def mse(y_hat, y): return ((y_hat-y)**2).mean()

# %% [markdown]
# Suppose we believe a = (-1.0,1.0) then we can compute y_hat which is our prediction and then compute our error.

# %%
a = tensor(-1.,1)

# %%
y_hat = x@a
mse(y_hat, y)
# Out:
# tensor(7.5077)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],y_hat);

# %% [markdown]
# So far we have specified the model (linear regression) and the evaluation criteria (or loss function). Now we need to handle optimization; that is, how do we find the best values for a? How do we find the best fitting linear regression.

# %% [markdown]
# # Gradient Descent
# We would like to find the values of a that minimize mse_loss.
#
# Gradient descent is an algorithm that minimizes functions. Given a function defined by a set of parameters, gradient descent starts with an initial set of parameter values and iteratively moves toward a set of parameter values that minimize the function. This iterative minimization is achieved by taking steps in the negative direction of the function gradient.
#
# Here is gradient descent implemented in [PyTorch.](http://pytorch.org/)

# %%
a = nn.Parameter(a); a
# Out:
# Parameter containing:
# tensor([-1.,  1.], requires_grad=True)

# %%
def update():
    y_hat = x@a
    loss = mse(y, y_hat)
    if t % 10 == 0: print(loss)
    loss.backward()
    with torch.no_grad():
        a.sub_(lr * a.grad)
        a.grad.zero_()

# %%
lr = 1e-1
for t in range(100): update()
# Out:
# tensor(7.5077, grad_fn=<MeanBackward0>)
# tensor(1.4977, grad_fn=<MeanBackward0>)
# tensor(0.4745, grad_fn=<MeanBackward0>)
# tensor(0.1932, grad_fn=<MeanBackward0>)
# tensor(0.1138, grad_fn=<MeanBackward0>)
# tensor(0.0913, grad_fn=<MeanBackward0>)
# tensor(0.0850, grad_fn=<MeanBackward0>)
# tensor(0.0832, grad_fn=<MeanBackward0>)
# tensor(0.0827, grad_fn=<MeanBackward0>)
# tensor(0.0826, grad_fn=<MeanBackward0>)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],x@a);

# %% [markdown]
# # Animate it!

# %%
from matplotlib import animation, rc
rc('animation', html='jshtml')

# %%
a = nn.Parameter(tensor(-1.,1))

fig = plt.figure()
plt.scatter(x[:,0], y, c='orange')
line, = plt.plot(x[:,0], x@a)
plt.close()

def animate(i):
    update()
    line.set_ydata(x@a)
    return line,

animation.FuncAnimation(fig, animate, np.arange(0, 100), interval=20)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img56cea2b6e3f84622853ca777541ecf4b">
#     <br>
#     <input id="_anim_slider56cea2b6e3f84622853ca777541ecf4b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim56cea2b6e3f84622853ca777541ecf4b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim56cea2b6e3f84622853ca777541ecf4b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select56cea2b6e3f84622853ca777541ecf4b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img56cea2b6e3f84622853ca777541ecf4b";
#     var slider_id = "_anim_slider56cea2b6e3f84622853ca777541ecf4b";
#     var loop_select_id = "_anim_loop_select56cea2b6e3f84622853ca777541ecf4b";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3X10VNX97/HPkARsxCcCKRiEJAR5\
# DlTC0+r1CYsKoq01Kpoqxbpil65ban9q+7v8Wl23UrS/PtEKtlk+1KUIrdYlvaDYVqytXLwYFRSf\
# qpKkQtGGRBRFCCT7/jHMkEzmTM7MnDNn9sz7tVZXyJkzc3YncT7Ze3/3PiFjjBEAAJbpF3QDAABI\
# BQEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIB\
# BgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYA\
# sBIBBgCwEgEGALASAQYAsBIBBgCwEgEGALASAQYAsBIBBgCwkjUBtnfvXtXW1mrs2LEaN26cNm/e\
# HHSTAAABKgy6AW4tXrxY559/vh599FF1dHRo//79QTcJABCgkDHGBN2Ivnz00UeaMmWKduzYoVAo\
# FHRzAABZwIoeWFNTk4YMGaJFixZp27Ztmjp1qpYvX65jjz3W8TmDBw9WeXl55hoJADmgublZe/bs\
# CboZrljRA2tsbNTMmTO1adMmzZgxQ4sXL9bxxx+vH/7whz3Oa2hoUENDgySptbVVLS0tQTQXAKxV\
# U1OjxsbGoJvhihVFHMOHD9fw4cM1Y8YMSVJtba1eeumlXufV19ersbFRjY2NGjJkSKabCQDIICsC\
# bOjQoTrllFP01ltvSZKefvppjR8/PuBWAQCCZMUcmCT96le/Ul1dnTo6OlRZWan7778/6CYBAAJk\
# TYBNmTLFmnFZAID/rBhCBAAgFgEGALZrWiU9Xi493C/8tWlV0C3KCGuGEAEAcTStkrbUS51Hdifa\
# 3xL+XpIq6oJrVwbQAwOAbOWmZ7VtydHwiujcHz6e4+iBAUA2aFoVDp39/5SKR0gnz5OaHui7Z7X/\
# n/Ffz+l4DqEHBgBBiwwD7m+RZMJf3/m1u55V8Yj4r+l0PIcQYAAQtHjDgHLY5W9/S8+hxMlLpYLi\
# nucUFIeP5zgCDACCluxw35b6oyFWUSdNb5CKR0oKhb9Ob8j5Ag6JOTAACF7xiCPDh7FCitsTiwwl\
# RkKqoi4vAisWPTAACEL3CsPDn0ihop6PFxRLVd90fn4eFGn0hQADgEyLLdroaJNCIamoRD2GAaev\
# PDI0GEceFGn0hSFEAMi0eEUbXR3SMQOlS2NuJjl5ac+FylLeFGn0hR4YAGSa49qtlt4LlvO4SKMv\
# 9MAAINMcizYUf8FynhZp9IUeGABkWry1W93lyVZQ6SLAACDTegwLOqDKsE8EGAAky4vbl1TUSV9p\
# psowDQQYACQj3r6F3XfGSFYebwWVLgIMAJLh9e1LqDJMGVWIAJAMP25fQpVhSuiBAUAynOamigb5\
# d00v5txyEAEGAMmYvLT3voWS1LnPfbAkE0hez7nlEGsCrLy8XJMmTdKUKVNUU1MTdHMA5KuKOqno\
# +N7HuzrczYMlG0hez7nlEKvmwJ555hkNHjw46GYAyHcd7fGPu5kHSxRI8ebB/JhzyxHW9MAAIGs4\
# zYO5WbuVaAspr6+V46wJsFAopHPPPVdTp05VQ0ND0M0BkM/SWbsVKkjuOOvEHFkzhPjcc8+prKxM\
# //73vzVnzhyNHTtWZ5xxRo9zGhoaouHW2toaRDMB5IPIUN+2JeGhvOIR4UBxUwpvOpM7ns61clzI\
# GBPnftXZ7bbbbtPAgQN10003OZ5TU1OjxsbGDLYKAFx4vDz+cGHxyPDWUgGz6bPTiiHETz/9VPv2\
# 7Yv++09/+pMmTpwYcKsAIAUMCXrGiiHEDz74QBdffLEk6fDhw7ryyit1/vnnB9w

# %% [markdown]
# # Vocab
# * Learning rate
# * Epoch
# * Minibatch
# * SGD
# * Model / Architecture
# * Parameters
# * Loss function
#
#
#
#
# For classification problems, we use cross entropy loss, also known as negative log likelihood loss. This penalizes incorrect confident predictions, and correct unconfident predictions.
